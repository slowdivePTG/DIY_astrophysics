# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
raw = np.loadtxt('planet1_rv.txt')
jd, rv, e = raw[:, 0], raw[:, 1], raw[:, 2]

# %%
from astropy.timeseries import LombScargle
import astropy.units as u

# %%
plt.errorbar(jd, rv, yerr=e, fmt = 'o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fre, power = LombScargle(jd, rv, dy=e).autopower(minimum_frequency=0.5,
                                           maximum_frequency=2.5,
                                           samples_per_peak=10)
plt.figure(figsize=(12, 8))
plt.plot(fre, power)
best_frequency = fre[power.argmax()]
best_frequency
# Out:
# 1.2864247221144454

# %%
best_frequency = fre[np.argmax(power)]
t_fit = np.linspace(0, 1 / best_frequency * 2, 1000)
y_fit = LS.model(t_fit, best_frequency)
plt.figure(figsize=(12, 8))
plt.plot(t_fit, y_fit)
plt.errorbar((jd) % (1 / best_frequency * 2), rv, yerr=e, fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>
