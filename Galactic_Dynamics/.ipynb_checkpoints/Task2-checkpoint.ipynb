# %%
import os

# %%
os.system('make')
os.system('./TwoBody')
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
raw1 = np.loadtxt('data_task2/R_V')
t, r1, r2 = raw1[:, 0], raw1[:, 1:3], raw1[:, 3:5]
v1, v2 = raw1[:, 5:7], raw1[:, 7:9]

# %%
plt.plot(r1[:, 0], r1[:, 1])
plt.plot(r2[:, 0], r2[:, 1])

# %%
f, ax = plt.subplots(figsize=(9, 6))

ax.set_xlabel(r'$t\ (\sqrt{R_0^3/GM})$', fontsize=20)
ax.set_ylabel(r'$\Delta E/E$', fontsize=20)
ax.tick_params(labelsize=20)
ax.grid()

dr = r1 - r2
q = 1e-5
m1, m2 = q / (1 + q), 1 / (1 + q)
K = 0.5 * m1 * (v1[:, 0]**2 + v1[:, 1]**2) + 0.5 * m2 * (v2[:, 0]**2 +
                                                         v2[:, 1]**2)
V = -m1 * m2 / np.sqrt(dr[:, 0]**2 + dr[:, 1]**2)
ax.plot(t, (K + V - (K[0]+V[0]))/(K[0]+V[0]))

f.tight_layout()
